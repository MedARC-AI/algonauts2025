# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import pandas as pd
import os
from tqdm import tqdm
import torch

# %%
# config
top_k = 5
all_models_path = './output_ensemble'
eval_set = ['life', 'bourne']
output_path = 'ensenmble_results/'

# %%
all_models = os.listdir(all_models_path)
print(f"Found {len(all_models)} models in {all_models_path}")
finished_all_models = []
def load_all_accuracies():
    accuracies = []
    for model in tqdm(all_models):
        ckpt_path = os.path.join(all_models_path, model, 'ckpt.pt')

        if not os.path.exists(ckpt_path):
            print(f"Checkpoint not found for model {model}, skipping.")
            continue
        
        try:
            ckpt = torch.load(ckpt_path, map_location='cpu', weights_only=False)
            all_acc_per_subject = []
            for i in [1,2,3,5]:
                mean_acc = 0
                for eval_movie in eval_set:
                    acc_cmovie = ckpt['metrics']['val_' + eval_movie][f'accmap_sub-{i}']
                    mean_acc = mean_acc + acc_cmovie
                all_acc_per_subject.append(mean_acc/len(eval_set))
            
            all_acc_per_subject = np.stack(all_acc_per_subject, axis=0)
            # print(all_acc_per_subject.shape)
            accuracies.append(all_acc_per_subject)
            finished_all_models.append(model)
        
        except Exception as e:
            print(f"Error loading checkpoint for model {model}: {e}")
            continue

    return np.stack(accuracies, axis=0)


accuracies_per_parcel = load_all_accuracies()
all_models = finished_all_models
# Out:
# Found 53 models in /home/cesar/algo_sub/algonauts2025/output_2
# 100%|██████████| 53/53 [00:00<00:00, 369.35it/s]
# Checkpoint not found for model feature_encoding_lr0.001_weight_decay0.1_encoder_kernel_size11_num_samples4000_sample_length32_batch_size32_epochs15_embed_dim128_transformer_depth4_pool_num_heads3_layers.20_layers.30, skipping.
# Checkpoint not found for model feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size33_num_samples4000_sample_length64_batch_size32_epochs10_embed_dim128_transformer_depth4_pool_num_heads2_layers.20_layers.20, skipping.
# Checkpoint not found for model feature_encoding_lr0.001_weight_decay0.1_encoder_kernel_size11_num_samples4000_sample_length32_batch_size32_epochs15_embed_dim128_transformer_depth4_pool_num_heads3_layers.30, skipping.
# Checkpoint not found for model feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size11_num_samples4000_sample_length64_batch_size16_epochs15_embed_dim128_transformer_depth4_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_encoder.layernorm_avg, skipping.

# %%
# find the model with the best accuracy for the average of subjects
acurracies_per_subject = np.mean(accuracies_per_parcel, axis=-1)
acurracies_per_model = np.mean(acurracies_per_subject, axis=-1)
best_model_index = np.argmax(acurracies_per_model)

print(f"Best model is {all_models[best_model_index]} with accuracy {acurracies_per_subject[best_model_index]}, mean: {acurracies_per_model[best_model_index]}")
# Out:
# Best model is feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg with accuracy [0.2181748  0.19460419 0.23472248 0.1770398 ], mean: 0.2061353176832199

# %%
num_models, num_subjects, num_parcels = accuracies_per_parcel.shape

# %%
ensemble_results = []

# Loop through each subject
for subject_id in range(num_subjects):
    # Loop through each parcel for the current subject
    for parcel_id in range(num_parcels):
        # Extract the accuracy scores for the current subject and parcel across all models
        model_accuracies = accuracies_per_parcel[:, subject_id, parcel_id]

        # Get the indices of the top-k models based on accuracy.
        # `np.argsort` returns the indices that would sort an array.
        # Slicing with `[-top_k:]` gives the indices of the top k highest values.
        top_model_indices = np.argsort(model_accuracies)[-top_k:]

        # Retrieve the names of the top k models using the indices
        top_model_names = [all_models[i] for i in top_model_indices]

        # Get the accuracy values of the top k models
        top_model_accuracies = model_accuracies[top_model_indices]

        # Calculate the expected performance by averaging the top k accuracies
        expected_performance = np.mean(top_model_accuracies)

        # Store the results
        ensemble_results.append({
            "subject_id": subject_id,
            "parcel_id": parcel_id,
            "top_models": top_model_names,
            "expected_performance": expected_performance,
        })

# %%
# replace subject_id with the actual subject number in the results
subject_map = {
    0: 1,  # Assuming subject IDs start from 1
    1: 2,
    2: 3,
    3: 5
}
for result in ensemble_results:
    result['subject_id'] = subject_map.get(result['subject_id'], result['subject_id'])
# calculate the expected_performance for each subject
expected_performance_per_subject = {}
for result in ensemble_results:
    subject_id = result['subject_id']
    if subject_id not in expected_performance_per_subject:
        expected_performance_per_subject[subject_id] = []
    expected_performance_per_subject[subject_id].append(result['expected_performance'])
# Average expected performance across parcels for each subject
average_expected_performance = {subject_id: np.mean(perfs) for subject_id, perfs in expected_performance_per_subject.items()}
print("\n--- Average Expected Performance per Subject ---")
for subject_id, avg_perf in average_expected_performance.items():
    print(f"Subject {subject_id}: {avg_perf:.4f}")
print(" Final average expected performance across all subjects: ", np.mean(list(average_expected_performance.values())))
# Out:
# --- Average Expected Performance per Subject ---
# Subject 1: 0.2248
# Subject 2: 0.2024
# Subject 3: 0.2420
# Subject 5: 0.1836
#  Final average expected performance across all subjects:  0.21318185

# %%
ensemble_results
# Out:
# [{'subject_id': 1,
#   'parcel_id': 0,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.23615408},
#  {'subject_id': 1,
#   'parcel_id': 1,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.3767295},
#  {'subject_id': 1,
#   'parcel_id': 2,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.37897623},
#  {'subject_id': 1,
#   'parcel_id': 3,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.4153567},
#  {'subject_id': 1,
#   'parcel_id': 4,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.30451187},
#  {'subject_id': 1,
#   'parcel_id': 5,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.48291147},
#  {'subject_id': 1,
#   'parcel_id': 6,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.40240753},
#  {'subject_id': 1,
#   'parcel_id': 7,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size33_num_samples1000_sample_length128_batch_size16_epochs15_embed_dim128_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.3847511},
#  {'subject_id': 1,
#   'parcel_id': 8,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.4263739},
#  {'subject_id': 1,
#   'parcel_id': 9,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.48965213},
#  {'subject_id': 1,
#   'parcel_id': 10,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.49499762},
#  {'subject_id': 1,
#   'parcel_id': 11,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.44880587},
#  {'subject_id': 1,
#   'parcel_id': 12,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.3511089},
#  {'subject_id': 1,
#   'parcel_id': 13,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.44621927},
#  {'subject_id': 1,
#   'parcel_id': 14,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.4165172},
#  {'subject_id': 1,
#   'parcel_id': 15,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.37282547},
#  {'subject_id': 1,
#   'parcel_id': 16,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.45241958},
#  {'subject_id': 1,
#   'parcel_id': 17,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.2558983},
#  {'subject_id': 1,
#   'parcel_id': 18,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.1_encoder_kernel_size11_num_samples1000_sample_length64_batch_size16_epochs15_embed_dim192_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.19544852},
#  {'subject_id': 1,
#   'parcel_id': 19,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.22828943},
#  {'subject_id': 1,
#   'parcel_id': 20,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.44975656},
#  {'subject_id': 1,
#   'parcel_id': 21,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.13051125},
#  {'subject_id': 1,
#   'parcel_id': 22,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.31112784},
#  {'subject_id': 1,
#   'parcel_id': 23,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.30905056},
#  {'subject_id': 1,
#   'parcel_id': 24,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.16188458},
#  {'subject_id': 1,
#   'parcel_id': 25,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.1_encoder_kernel_size11_num_samples1000_sample_length64_batch_size16_epochs15_embed_dim192_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.16030484},
#  {'subject_id': 1,
#   'parcel_id': 26,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.41111356},
#  {'subject_id': 1,
#   'parcel_id': 27,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.48616475},
#  {'subject_id': 1,
#   'parcel_id': 28,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.4974627},
#  {'subject_id': 1,
#   'parcel_id': 29,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.44191474},
#  {'subject_id': 1,
#   'parcel_id': 30,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.18935049},
#  {'subject_id': 1,
#   'parcel_id': 31,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.13484395},
#  {'subject_id': 1,
#   'parcel_id': 32,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.44536442},
#  {'subject_id': 1,
#   'parcel_id': 33,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.4878329},
#  {'subject_id': 1,
#   'parcel_id': 34,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_encoder.layernorm_avg'],
#   'expected_performance': 0.302921},
#  {'subject_id': 1,
#   'parcel_id': 35,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.52003586},
#  {'subject_id': 1,
#   'parcel_id': 36,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.1664405},
#  {'subject_id': 1,
#   'parcel_id': 37,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.1_encoder_kernel_size11_num_samples1000_sample_length64_batch_size16_epochs15_embed_dim192_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.21008568},
#  {'subject_id': 1,
#   'parcel_id': 38,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.5269622},
#  {'subject_id': 1,
#   'parcel_id': 39,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.39487442},
#  {'subject_id': 1,
#   'parcel_id': 40,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.13993888},
#  {'subject_id': 1,
#   'parcel_id': 41,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.6013377},
#  {'subject_id': 1,
#   'parcel_id': 42,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.38843834},
#  {'subject_id': 1,
#   'parcel_id': 43,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.46051925},
#  {'subject_id': 1,
#   'parcel_id': 44,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.5787752},
#  {'subject_id': 1,
#   'parcel_id': 45,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.22747168},
#  {'subject_id': 1,
#   'parcel_id': 46,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.27278313},
#  {'subject_id': 1,
#   'parcel_id': 47,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.17264603},
#  {'subject_id': 1,
#   'parcel_id': 48,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.49019593},
#  {'subject_id': 1,
#   'parcel_id': 49,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size33_num_samples1000_sample_length128_batch_size16_epochs15_embed_dim128_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.22364128},
#  {'subject_id': 1,
#   'parcel_id': 50,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.31389678},
#  {'subject_id': 1,
#   'parcel_id': 51,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.36510515},
#  {'subject_id': 1,
#   'parcel_id': 52,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.47550815},
#  {'subject_id': 1,
#   'parcel_id': 53,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.4688391},
#  {'subject_id': 1,
#   'parcel_id': 54,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.1721106},
#  {'subject_id': 1,
#   'parcel_id': 55,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.1_encoder_kernel_size11_num_samples1000_sample_length64_batch_size16_epochs15_embed_dim192_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.24600731},
#  {'subject_id': 1,
#   'parcel_id': 56,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.25106487},
#  {'subject_id': 1,
#   'parcel_id': 57,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.5339699},
#  {'subject_id': 1,
#   'parcel_id': 58,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size33_num_samples4000_sample_length64_batch_size32_epochs10_embed_dim128_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.4015135},
#  {'subject_id': 1,
#   'parcel_id': 59,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.29734385},
#  {'subject_id': 1,
#   'parcel_id': 60,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.56984943},
#  {'subject_id': 1,
#   'parcel_id': 61,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.3695886},
#  {'subject_id': 1,
#   'parcel_id': 62,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.22942442},
#  {'subject_id': 1,
#   'parcel_id': 63,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.4884914},
#  {'subject_id': 1,
#   'parcel_id': 64,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.43963158},
#  {'subject_id': 1,
#   'parcel_id': 65,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.22164425},
#  {'subject_id': 1,
#   'parcel_id': 66,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.2474578},
#  {'subject_id': 1,
#   'parcel_id': 67,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.45811325},
#  {'subject_id': 1,
#   'parcel_id': 68,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.23489851},
#  {'subject_id': 1,
#   'parcel_id': 69,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.54532135},
#  {'subject_id': 1,
#   'parcel_id': 70,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.29189438},
#  {'subject_id': 1,
#   'parcel_id': 71,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.41631854},
#  {'subject_id': 1,
#   'parcel_id': 72,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.43624055},
#  {'subject_id': 1,
#   'parcel_id': 73,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.4143315},
#  {'subject_id': 1,
#   'parcel_id': 74,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.27997985},
#  {'subject_id': 1,
#   'parcel_id': 75,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.46569493},
#  {'subject_id': 1,
#   'parcel_id': 76,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.47591558},
#  {'subject_id': 1,
#   'parcel_id': 77,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.27012098},
#  {'subject_id': 1,
#   'parcel_id': 78,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.2942735},
#  {'subject_id': 1,
#   'parcel_id': 79,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.37208024},
#  {'subject_id': 1,
#   'parcel_id': 80,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.25951952},
#  {'subject_id': 1,
#   'parcel_id': 81,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.32823217},
#  {'subject_id': 1,
#   'parcel_id': 82,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.51954865},
#  {'subject_id': 1,
#   'parcel_id': 83,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.7848941},
#  {'subject_id': 1,
#   'parcel_id': 84,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.01_encoder_kernel_size45_num_samples1000_sample_length64_batch_size8_epochs15_embed_dim128_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.75087917},
#  {'subject_id': 1,
#   'parcel_id': 85,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.46994254},
#  {'subject_id': 1,
#   'parcel_id': 86,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11'],
#   'expected_performance': 0.20077612},
#  {'subject_id': 1,
#   'parcel_id': 87,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.01_encoder_kernel_size45_num_samples1000_sample_length64_batch_size8_epochs15_embed_dim128_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.7480515},
#  {'subject_id': 1,
#   'parcel_id': 88,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.01_encoder_kernel_size45_num_samples1000_sample_length64_batch_size8_epochs15_embed_dim128_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.7214353},
#  {'subject_id': 1,
#   'parcel_id': 89,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.01_encoder_kernel_size45_num_samples1000_sample_length64_batch_size8_epochs15_embed_dim128_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.6283065},
#  {'subject_id': 1,
#   'parcel_id': 90,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11'],
#   'expected_performance': 0.22680503},
#  {'subject_id': 1,
#   'parcel_id': 91,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11'],
#   'expected_performance': 0.23736432},
#  {'subject_id': 1,
#   'parcel_id': 92,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.096927695},
#  {'subject_id': 1,
#   'parcel_id': 93,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.01_encoder_kernel_size45_num_samples1000_sample_length64_batch_size8_epochs15_embed_dim128_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.7034611},
#  {'subject_id': 1,
#   'parcel_id': 94,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.01_encoder_kernel_size45_num_samples1000_sample_length64_batch_size8_epochs15_embed_dim128_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.3742427},
#  {'subject_id': 1,
#   'parcel_id': 95,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12'],
#   'expected_performance': 0.33992457},
#  {'subject_id': 1,
#   'parcel_id': 96,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.1839213},
#  {'subject_id': 1,
#   'parcel_id': 97,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.12750234},
#  {'subject_id': 1,
#   'parcel_id': 98,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.2218264},
#  {'subject_id': 1,
#   'parcel_id': 99,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.5304129},
#  {'subject_id': 1,
#   'parcel_id': 100,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.33120257},
#  {'subject_id': 1,
#   'parcel_id': 101,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.21898302},
#  {'subject_id': 1,
#   'parcel_id': 102,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.1_encoder_kernel_size11_num_samples1000_sample_length64_batch_size16_epochs15_embed_dim192_transformer_depth4_pool_num_heads2_layers.20_layers.20'],
#   'expected_performance': 0.13788939},
#  {'subject_id': 1,
#   'parcel_id': 103,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.33911955},
#  {'subject_id': 1,
#   'parcel_id': 104,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.17713138},
#  {'subject_id': 1,
#   'parcel_id': 105,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.3899361},
#  {'subject_id': 1,
#   'parcel_id': 106,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.36323684},
#  {'subject_id': 1,
#   'parcel_id': 107,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.17507407},
#  {'subject_id': 1,
#   'parcel_id': 108,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.21425954},
#  {'subject_id': 1,
#   'parcel_id': 109,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11'],
#   'expected_performance': 0.17407894},
#  {'subject_id': 1,
#   'parcel_id': 110,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.20290133},
#  {'subject_id': 1,
#   'parcel_id': 111,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.23241407},
#  {'subject_id': 1,
#   'parcel_id': 112,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size11_num_samples4000_sample_length64_batch_size16_epochs15_embed_dim128_transformer_depth4_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.1994142},
#  {'subject_id': 1,
#   'parcel_id': 113,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.1_encoder_kernel_size11_num_samples1000_sample_length64_batch_size16_epochs15_embed_dim192_transformer_depth4_pool_num_heads2_layers.20_layers.20'],
#   'expected_performance': 0.1172272},
#  {'subject_id': 1,
#   'parcel_id': 114,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12'],
#   'expected_performance': 0.08477381},
#  {'subject_id': 1,
#   'parcel_id': 115,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.12128109},
#  {'subject_id': 1,
#   'parcel_id': 116,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size45_num_samples2000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.117911994},
#  {'subject_id': 1,
#   'parcel_id': 117,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.12_encoder.layernorm_avg'],
#   'expected_performance': 0.08210652},
#  {'subject_id': 1,
#   'parcel_id': 118,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.13524884},
#  {'subject_id': 1,
#   'parcel_id': 119,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.22314247},
#  {'subject_id': 1,
#   'parcel_id': 120,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.1_encoder_kernel_size11_num_samples1000_sample_length64_batch_size16_epochs15_embed_dim192_transformer_depth4_pool_num_heads2_layers.20_layers.20'],
#   'expected_performance': 0.111947075},
#  {'subject_id': 1,
#   'parcel_id': 121,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size45_num_samples2000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth6_pool_num_heads3_layers.20'],
#   'expected_performance': 0.14199075},
#  {'subject_id': 1,
#   'parcel_id': 122,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.11578492},
#  {'subject_id': 1,
#   'parcel_id': 123,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20'],
#   'expected_performance': 0.31065893},
#  {'subject_id': 1,
#   'parcel_id': 124,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.054976888},
#  {'subject_id': 1,
#   'parcel_id': 125,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.17472756},
#  {'subject_id': 1,
#   'parcel_id': 126,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.13518941},
#  {'subject_id': 1,
#   'parcel_id': 127,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.09750328},
#  {'subject_id': 1,
#   'parcel_id': 128,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.09279278},
#  {'subject_id': 1,
#   'parcel_id': 129,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.1642337},
#  {'subject_id': 1,
#   'parcel_id': 130,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.09654967},
#  {'subject_id': 1,
#   'parcel_id': 131,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.1238392},
#  {'subject_id': 1,
#   'parcel_id': 132,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size33_num_samples1000_sample_length128_batch_size16_epochs15_embed_dim128_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.09426712},
#  {'subject_id': 1,
#   'parcel_id': 133,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.28471613},
#  {'subject_id': 1,
#   'parcel_id': 134,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size33_num_samples4000_sample_length64_batch_size32_epochs10_embed_dim128_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.11473827},
#  {'subject_id': 1,
#   'parcel_id': 135,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.17003645},
#  {'subject_id': 1,
#   'parcel_id': 136,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.095156536},
#  {'subject_id': 1,
#   'parcel_id': 137,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.107906096},
#  {'subject_id': 1,
#   'parcel_id': 138,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.07634571},
#  {'subject_id': 1,
#   'parcel_id': 139,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.32680005},
#  {'subject_id': 1,
#   'parcel_id': 140,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.13174406},
#  {'subject_id': 1,
#   'parcel_id': 141,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.26101464},
#  {'subject_id': 1,
#   'parcel_id': 142,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size33_num_samples1000_sample_length128_batch_size16_epochs15_embed_dim128_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.09164664},
#  {'subject_id': 1,
#   'parcel_id': 143,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size11_num_samples4000_sample_length64_batch_size16_epochs15_embed_dim128_transformer_depth4_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.26847154},
#  {'subject_id': 1,
#   'parcel_id': 144,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.13457364},
#  {'subject_id': 1,
#   'parcel_id': 145,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.14191845},
#  {'subject_id': 1,
#   'parcel_id': 146,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.14267595},
#  {'subject_id': 1,
#   'parcel_id': 147,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20'],
#   'expected_performance': 0.1137436},
#  {'subject_id': 1,
#   'parcel_id': 148,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size45_num_samples2000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth6_pool_num_heads3_layers.20'],
#   'expected_performance': 0.08832393},
#  {'subject_id': 1,
#   'parcel_id': 149,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.18089186},
#  {'subject_id': 1,
#   'parcel_id': 150,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size11_num_samples4000_sample_length64_batch_size16_epochs15_embed_dim128_transformer_depth4_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.19800362},
#  {'subject_id': 1,
#   'parcel_id': 151,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size11_num_samples4000_sample_length64_batch_size16_epochs15_embed_dim128_transformer_depth4_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.13013694},
#  {'subject_id': 1,
#   'parcel_id': 152,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.12245789},
#  {'subject_id': 1,
#   'parcel_id': 153,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.08412363},
#  {'subject_id': 1,
#   'parcel_id': 154,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.15483427},
#  {'subject_id': 1,
#   'parcel_id': 155,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size11_num_samples4000_sample_length64_batch_size16_epochs15_embed_dim128_transformer_depth4_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.13925356},
#  {'subject_id': 1,
#   'parcel_id': 156,
# ...
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.17479283},
#  {'subject_id': 1,
#   'parcel_id': 950,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.1751469},
#  {'subject_id': 1,
#   'parcel_id': 951,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.16239133},
#  {'subject_id': 1,
#   'parcel_id': 952,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.18924409},
#  {'subject_id': 1,
#   'parcel_id': 953,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.20660555},
#  {'subject_id': 1,
#   'parcel_id': 954,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.01_encoder_kernel_size45_num_samples1000_sample_length64_batch_size8_epochs15_embed_dim128_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.22796014},
#  {'subject_id': 1,
#   'parcel_id': 955,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20'],
#   'expected_performance': 0.2651844},
#  {'subject_id': 1,
#   'parcel_id': 956,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.005895186},
#  {'subject_id': 1,
#   'parcel_id': 957,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.017335083},
#  {'subject_id': 1,
#   'parcel_id': 958,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.157917},
#  {'subject_id': 1,
#   'parcel_id': 959,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.07928742},
#  {'subject_id': 1,
#   'parcel_id': 960,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.14877717},
#  {'subject_id': 1,
#   'parcel_id': 961,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.11'],
#   'expected_performance': 0.13175593},
#  {'subject_id': 1,
#   'parcel_id': 962,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size11_num_samples4000_sample_length64_batch_size16_epochs15_embed_dim128_transformer_depth4_pool_num_heads3_layers.20'],
#   'expected_performance': 0.14213493},
#  {'subject_id': 1,
#   'parcel_id': 963,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.19343027},
#  {'subject_id': 1,
#   'parcel_id': 964,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.01_encoder_kernel_size45_num_samples1000_sample_length64_batch_size8_epochs15_embed_dim128_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.050134785},
#  {'subject_id': 1,
#   'parcel_id': 965,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.18069512},
#  {'subject_id': 1,
#   'parcel_id': 966,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.17294441},
#  {'subject_id': 1,
#   'parcel_id': 967,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.031632826},
#  {'subject_id': 1,
#   'parcel_id': 968,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.2571525},
#  {'subject_id': 1,
#   'parcel_id': 969,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.24511586},
#  {'subject_id': 1,
#   'parcel_id': 970,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size33_num_samples1000_sample_length128_batch_size16_epochs15_embed_dim128_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.19370303},
#  {'subject_id': 1,
#   'parcel_id': 971,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.20499115},
#  {'subject_id': 1,
#   'parcel_id': 972,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.18439469},
#  {'subject_id': 1,
#   'parcel_id': 973,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.01_encoder_kernel_size45_num_samples1000_sample_length64_batch_size8_epochs15_embed_dim128_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.17373398},
#  {'subject_id': 1,
#   'parcel_id': 974,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.1475698},
#  {'subject_id': 1,
#   'parcel_id': 975,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.23154244},
#  {'subject_id': 1,
#   'parcel_id': 976,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size45_num_samples1000_sample_length128_batch_size8_epochs15_embed_dim256_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.3234435},
#  {'subject_id': 1,
#   'parcel_id': 977,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.01_encoder_kernel_size45_num_samples1000_sample_length64_batch_size8_epochs15_embed_dim128_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.18601455},
#  {'subject_id': 1,
#   'parcel_id': 978,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size33_num_samples1000_sample_length128_batch_size16_epochs15_embed_dim128_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.21520938},
#  {'subject_id': 1,
#   'parcel_id': 979,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size33_num_samples1000_sample_length128_batch_size16_epochs15_embed_dim128_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.23786841},
#  {'subject_id': 1,
#   'parcel_id': 980,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.15111819},
#  {'subject_id': 1,
#   'parcel_id': 981,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.20_layers.20'],
#   'expected_performance': 0.22262608},
#  {'subject_id': 1,
#   'parcel_id': 982,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.075939335},
#  {'subject_id': 1,
#   'parcel_id': 983,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.24523309},
#  {'subject_id': 1,
#   'parcel_id': 984,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11'],
#   'expected_performance': 0.08461502},
#  {'subject_id': 1,
#   'parcel_id': 985,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.1364795},
#  {'subject_id': 1,
#   'parcel_id': 986,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.13072383},
#  {'subject_id': 1,
#   'parcel_id': 987,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.01_encoder_kernel_size45_num_samples1000_sample_length64_batch_size8_epochs15_embed_dim128_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.12714198},
#  {'subject_id': 1,
#   'parcel_id': 988,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.16773348},
#  {'subject_id': 1,
#   'parcel_id': 989,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.16588774},
#  {'subject_id': 1,
#   'parcel_id': 990,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size33_num_samples4000_sample_length32_batch_size8_epochs10_embed_dim192_transformer_depth4_pool_num_heads2_layers.20'],
#   'expected_performance': 0.13275354},
#  {'subject_id': 1,
#   'parcel_id': 991,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.1_encoder_kernel_size33_num_samples4000_sample_length64_batch_size32_epochs10_embed_dim128_transformer_depth4_pool_num_heads2_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.17556593},
#  {'subject_id': 1,
#   'parcel_id': 992,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.01_encoder_kernel_size45_num_samples1000_sample_length64_batch_size8_epochs15_embed_dim128_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.13984},
#  {'subject_id': 1,
#   'parcel_id': 993,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20'],
#   'expected_performance': 0.109524935},
#  {'subject_id': 1,
#   'parcel_id': 994,
#   'top_models': ['feature_encoding_lr0.001_weight_decay0.3_encoder_kernel_size45_num_samples1000_sample_length128_batch_size32_epochs20_embed_dim256_transformer_depth6_pool_num_heads4_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.17045256},
#  {'subject_id': 1,
#   'parcel_id': 995,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.1914353},
#  {'subject_id': 1,
#   'parcel_id': 996,
#   'top_models': ['feature_encoding_lr0.0003_weight_decay0.3_encoder_kernel_size65_num_samples1000_sample_length32_batch_size16_epochs15_embed_dim256_transformer_depth6_pool_num_heads3_layers.20_encoder.layernorm_avg_layers.12'],
#   'expected_performance': 0.22775939},
#  {'subject_id': 1,
#   'parcel_id': 997,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.2084375},
#  {'subject_id': 1,
#   'parcel_id': 998,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.24322128},
#  {'subject_id': 1,
#   'parcel_id': 999,
#   'top_models': ['feature_encoding_lr0.0001_weight_decay0.3_encoder_kernel_size65_num_samples4000_sample_length32_batch_size32_epochs10_embed_dim128_transformer_depth6_pool_num_heads3_layers.11_layers.12_layers.20_layers.20_layers.20_encoder.layernorm_avg'],
#   'expected_performance': 0.17593601},
#  ...]

# %%
def load_all_model_submissions():
    all_submissions = {}
    for model in tqdm(all_models):
        submission_path = os.path.join(all_models_path, model, 'fmri_predictions_ood.npy')
        if not os.path.exists(submission_path):
            print(f"Submission file not found for model {model}, skipping.")
            continue
        
        try:
            submission = np.load(submission_path, allow_pickle=True).item()
            all_submissions[model] = submission
        except Exception as e:
            print(f"Error loading submission for model {model}: {e}")
            continue

    return all_submissions

all_model_submissions = load_all_model_submissions()
# Out:
# 100%|██████████| 49/49 [00:03<00:00, 13.67it/s]

# %%
example_submission = np.load(f'output_2/{all_models[-1]}/fmri_predictions_ood.npy', allow_pickle=True).item()

# %%
empty_submission = {subject: {} for subject in example_submission.keys()}
for subject, preds in example_submission.items():
    for movie, pred in preds.items():
        empty_submission[subject][movie] = np.zeros_like(pred)

for subject, preds in empty_submission.items():
    for movie, pred in preds.items():
        print(f"Subject: {subject}, Movie: {movie}, Prediction Shape: {pred.shape}")
        assert np.allclose(pred, np.zeros_like(pred)), "Predictions are not initialized to zero."
# Out:
# Subject: sub-01, Movie: chaplin1, Prediction Shape: (432, 1000)
# Subject: sub-01, Movie: chaplin2, Prediction Shape: (405, 1000)
# Subject: sub-01, Movie: mononoke1, Prediction Shape: (423, 1000)
# Subject: sub-01, Movie: mononoke2, Prediction Shape: (426, 1000)
# Subject: sub-01, Movie: passepartout1, Prediction Shape: (422, 1000)
# Subject: sub-01, Movie: passepartout2, Prediction Shape: (436, 1000)
# Subject: sub-01, Movie: planetearth1, Prediction Shape: (433, 1000)
# Subject: sub-01, Movie: planetearth2, Prediction Shape: (418, 1000)
# Subject: sub-01, Movie: pulpfiction1, Prediction Shape: (468, 1000)
# Subject: sub-01, Movie: pulpfiction2, Prediction Shape: (378, 1000)
# Subject: sub-01, Movie: wot1, Prediction Shape: (353, 1000)
# Subject: sub-01, Movie: wot2, Prediction Shape: (324, 1000)
# Subject: sub-02, Movie: chaplin1, Prediction Shape: (432, 1000)
# Subject: sub-02, Movie: chaplin2, Prediction Shape: (405, 1000)
# Subject: sub-02, Movie: mononoke1, Prediction Shape: (423, 1000)
# Subject: sub-02, Movie: mononoke2, Prediction Shape: (426, 1000)
# Subject: sub-02, Movie: passepartout1, Prediction Shape: (422, 1000)
# Subject: sub-02, Movie: passepartout2, Prediction Shape: (436, 1000)
# Subject: sub-02, Movie: planetearth1, Prediction Shape: (433, 1000)
# Subject: sub-02, Movie: planetearth2, Prediction Shape: (418, 1000)
# Subject: sub-02, Movie: pulpfiction1, Prediction Shape: (468, 1000)
# Subject: sub-02, Movie: pulpfiction2, Prediction Shape: (378, 1000)
# Subject: sub-02, Movie: wot1, Prediction Shape: (353, 1000)
# Subject: sub-02, Movie: wot2, Prediction Shape: (324, 1000)
# Subject: sub-03, Movie: chaplin1, Prediction Shape: (432, 1000)
# Subject: sub-03, Movie: chaplin2, Prediction Shape: (405, 1000)
# Subject: sub-03, Movie: mononoke1, Prediction Shape: (423, 1000)
# Subject: sub-03, Movie: mononoke2, Prediction Shape: (426, 1000)
# Subject: sub-03, Movie: passepartout1, Prediction Shape: (422, 1000)
# Subject: sub-03, Movie: passepartout2, Prediction Shape: (436, 1000)
# Subject: sub-03, Movie: planetearth1, Prediction Shape: (433, 1000)
# Subject: sub-03, Movie: planetearth2, Prediction Shape: (418, 1000)
# Subject: sub-03, Movie: pulpfiction1, Prediction Shape: (468, 1000)
# Subject: sub-03, Movie: pulpfiction2, Prediction Shape: (378, 1000)
# Subject: sub-03, Movie: wot1, Prediction Shape: (353, 1000)
# Subject: sub-03, Movie: wot2, Prediction Shape: (324, 1000)
# Subject: sub-05, Movie: chaplin1, Prediction Shape: (432, 1000)
# Subject: sub-05, Movie: chaplin2, Prediction Shape: (405, 1000)
# Subject: sub-05, Movie: mononoke1, Prediction Shape: (423, 1000)
# Subject: sub-05, Movie: mononoke2, Prediction Shape: (426, 1000)
# Subject: sub-05, Movie: passepartout1, Prediction Shape: (422, 1000)
# Subject: sub-05, Movie: passepartout2, Prediction Shape: (436, 1000)
# Subject: sub-05, Movie: planetearth1, Prediction Shape: (433, 1000)
# Subject: sub-05, Movie: planetearth2, Prediction Shape: (418, 1000)
# Subject: sub-05, Movie: pulpfiction1, Prediction Shape: (468, 1000)
# Subject: sub-05, Movie: pulpfiction2, Prediction Shape: (378, 1000)
# Subject: sub-05, Movie: wot1, Prediction Shape: (353, 1000)
# Subject: sub-05, Movie: wot2, Prediction Shape: (324, 1000)

# %%
empty_submission['sub-01'].keys()
# Out:
# dict_keys(['chaplin1', 'chaplin2', 'mononoke1', 'mononoke2', 'passepartout1', 'passepartout2', 'planetearth1', 'planetearth2', 'pulpfiction1', 'pulpfiction2', 'wot1', 'wot2'])

# %%
# Final ensemble predictions
ensemble_predictions = empty_submission.copy()
for subject_id in range(num_subjects):
    for parcel_id in tqdm(range(num_parcels)):
        # Get the top k models for the current subject and parcel
        top_models = [result['top_models'] for result in ensemble_results if result['subject_id'] == subject_map[subject_id] and result['parcel_id'] == parcel_id]
        
        if not top_models:
            print(f"No top models found for subject {subject_id+1}, parcel {parcel_id}. Skipping.")
            continue
        
        top_models = top_models[0]  # Get the first (and only) entry since we looped through all subjects and parcels

        # Average the predictions from the top k models
        predictions = []
        for model in top_models:
            if model in all_model_submissions:
                preds = all_model_submissions[model][f'sub-0{subject_map[subject_id]}']
                predictions.append(preds)
            else:
                print(f"Model {model} not found in submissions, skipping.")

        if predictions:
            for movie in example_submission[f'sub-0{subject_map[subject_id]}'].keys():
                # Average the predictions for the current movie
                avg_prediction = np.mean([preds[movie] for preds in predictions], axis=0)
                ensemble_predictions[f'sub-0{subject_map[subject_id]}'][movie][:, parcel_id] = avg_prediction[:, parcel_id]
# Out:
# 100%|██████████| 1000/1000 [00:08<00:00, 111.89it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 108.74it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 116.73it/s]
# 100%|██████████| 1000/1000 [00:08<00:00, 115.31it/s]

# %%
# check if there are zeros in the ensemble predictions
for subject, preds in ensemble_predictions.items():
    for movie, pred in preds.items():
        if np.any(pred == 0):
            print(f"Found zeros in predictions for {subject}, {movie}.")
            # Count how many zeros are in the predictions
            zero_count = np.sum(pred == 0)
            print(f"Number of zeros in predictions for {subject}, {movie}: {zero_count}")
        else:
            print(f"No zeros in predictions for {subject}, {movie}.")
ensemble_predictions
# Out:
# No zeros in predictions for sub-01, chaplin1.
# No zeros in predictions for sub-01, chaplin2.
# No zeros in predictions for sub-01, mononoke1.
# No zeros in predictions for sub-01, mononoke2.
# No zeros in predictions for sub-01, passepartout1.
# No zeros in predictions for sub-01, passepartout2.
# No zeros in predictions for sub-01, planetearth1.
# No zeros in predictions for sub-01, planetearth2.
# No zeros in predictions for sub-01, pulpfiction1.
# No zeros in predictions for sub-01, pulpfiction2.
# No zeros in predictions for sub-01, wot1.
# No zeros in predictions for sub-01, wot2.
# No zeros in predictions for sub-02, chaplin1.
# No zeros in predictions for sub-02, chaplin2.
# No zeros in predictions for sub-02, mononoke1.
# No zeros in predictions for sub-02, mononoke2.
# No zeros in predictions for sub-02, passepartout1.
# No zeros in predictions for sub-02, passepartout2.
# No zeros in predictions for sub-02, planetearth1.
# No zeros in predictions for sub-02, planetearth2.
# No zeros in predictions for sub-02, pulpfiction1.
# Found zeros in predictions for sub-02, pulpfiction2.
# Number of zeros in predictions for sub-02, pulpfiction2: 1
# No zeros in predictions for sub-02, wot1.
# No zeros in predictions for sub-02, wot2.
# No zeros in predictions for sub-03, chaplin1.
# No zeros in predictions for sub-03, chaplin2.
# No zeros in predictions for sub-03, mononoke1.
# No zeros in predictions for sub-03, mononoke2.
# No zeros in predictions for sub-03, passepartout1.
# No zeros in predictions for sub-03, passepartout2.
# No zeros in predictions for sub-03, planetearth1.
# No zeros in predictions for sub-03, planetearth2.
# No zeros in predictions for sub-03, pulpfiction1.
# No zeros in predictions for sub-03, pulpfiction2.
# No zeros in predictions for sub-03, wot1.
# No zeros in predictions for sub-03, wot2.
# No zeros in predictions for sub-05, chaplin1.
# No zeros in predictions for sub-05, chaplin2.
# No zeros in predictions for sub-05, mononoke1.
# No zeros in predictions for sub-05, mononoke2.
# No zeros in predictions for sub-05, passepartout1.
# No zeros in predictions for sub-05, passepartout2.
# No zeros in predictions for sub-05, planetearth1.
# No zeros in predictions for sub-05, planetearth2.
# No zeros in predictions for sub-05, pulpfiction1.
# No zeros in predictions for sub-05, pulpfiction2.
# No zeros in predictions for sub-05, wot1.
# No zeros in predictions for sub-05, wot2.
# {'sub-01': {'chaplin1': array([[-0.09750009, -0.1972368 , -0.29033697, ...,  0.03508082,
#           -0.06536325, -0.00117031],
#          [-0.12326148, -0.2798772 , -0.2781374 , ...,  0.10312617,
#           -0.00573307,  0.05987582],
#          [-0.13214545, -0.33786988, -0.23733516, ...,  0.05759467,
#            0.14454304,  0.12735866],
#          ...,
#          [ 0.05571396,  0.17526698,  0.3312317 , ...,  0.00092853,
#            0.27909514,  0.21525803],
#          [-0.11932096, -0.36749566, -0.02338677, ...,  0.07904674,
#            0.392294  ,  0.2895323 ],
#          [-0.27589047, -0.87652075, -0.28853065, ...,  0.20491427,
#            0.5332804 ,  0.41263485]], dtype=float32),
#   'chaplin2': array([[-0.02521061, -0.11490208, -0.10303237, ..., -0.01441721,
#           -0.03883632, -0.01306938],
#          [-0.02931923, -0.19078416, -0.20218645, ..., -0.01194705,
#           -0.03531433, -0.01653899],
#          [-0.10861367, -0.39401174, -0.3144456 , ...,  0.004867  ,
#            0.18365416,  0.11503664],
#          ...,
#          [ 0.06338393,  0.0687506 ,  0.19110465, ..., -0.14471595,
#            0.31318185,  0.15536042],
#          [-0.1509824 , -0.4342506 , -0.10542424, ..., -0.0372376 ,
#            0.45093316,  0.25730604],
#          [-0.31982917, -0.9535003 , -0.37181288, ...,  0.08962072,
#            0.59680796,  0.3450516 ]], dtype=float32),
#   'mononoke1': array([[-0.02110611, -0.02722331, -0.3457138 , ...,  0.2500286 ,
#           -0.11258294,  0.06407291],
#          [-0.01588256, -0.07279173, -0.3793369 , ...,  0.2582322 ,
#           -0.05785844,  0.09883945],
#          [ 0.00497207, -0.13478482, -0.31840444, ...,  0.26912495,
#            0.05471165,  0.21365857],
#          ...,
#          [-0.11159388, -0.19504695,  0.07732078, ...,  0.32866108,
#            0.05118556,  0.24364972],
#          [-0.046884  , -0.10655554,  0.05132716, ...,  0.33781403,
#            0.04551184,  0.2489491 ],
#          [-0.0381723 , -0.0963885 , -0.02392984, ...,  0.31099838,
#            0.08401062,  0.2739242 ]], dtype=float32),
#   'mononoke2': array([[-0.10380594, -0.25437924, -0.3363564 , ..., -0.01696469,
#            0.05235044, -0.02687904],
#          [-0.12132229, -0.33025986, -0.36311328, ..., -0.03582957,
#            0.05033928, -0.01205404],
#          [-0.12902518, -0.32698515, -0.29825848, ..., -0.10104028,
#            0.10385115, -0.02213993],
#          ...,
#          [-0.01086888,  0.15009725,  0.14862975, ...,  0.06337558,
#            0.05079468,  0.01727187],
#          [ 0.0243722 ,  0.15376356,  0.02024148, ...,  0.16106242,
#           -0.09422193, -0.00514355],
#          [ 0.01556569,  0.09066932, -0.05648657, ...,  0.21001416,
#           -0.13745986,  0.00460855]], dtype=float32),
#   'passepartout1': array([[-0.07567278, -0.2202952 ,  0.01431705, ...,  0.11571877,
#            0.1640827 ,  0.18306151],
#          [-0.09177704, -0.23066309,  0.06564946, ...,  0.11679669,
#            0.20442437,  0.16977365],
#          [-0.11075877, -0.42443812, -0.01754257, ...,  0.15963866,
#            0.4263695 ,  0.32128888],
#          ...,
#          [ 0.01526403,  0.08115606, -0.02529829, ..., -0.44303465,
#           -0.42254165, -0.47863382],
#          [-0.08200476, -0.18416923, -0.0247259 , ..., -0.26290506,
#           -0.11190938, -0.2435731 ],
#          [-0.2170489 , -0.54474914, -0.08870422, ..., -0.06979731,
#            0.1313567 , -0.05564693]], dtype=float32),
#   'passepartout2': array([[ 0.00534841, -0.12722422, -0.18318062, ...,  0.0226713 ,
#            0.01948195, -0.00924332],
#          [ 0.01856254, -0.17957419, -0.16293673, ..., -0.01995572,
#            0.03526368, -0.02227037],
#          [ 0.02682452, -0.20202428, -0.204366  , ..., -0.030085  ,
#            0.12773305,  0.02880758],
#          ...,
#          [ 0.10389102,  0.25911343, -0.33459264, ..., -0.02501539,
#           -0.1811138 , -0.14148903],
#          [ 0.08561067,  0.1438943 , -0.295253  , ...,  0.03684216,
#           -0.13605036, -0.07972161],
#          [-0.02946103, -0.16326745, -0.21938701, ...,  0.13162553,
#            0.09439632,  0.09621666]], dtype=float32),
#   'planetearth1': array([[-0.10709259, -0.17305991, -0.42288068, ...,  0.28686774,
#            0.00147989,  0.20921756],
#          [-0.10407181, -0.2420268 , -0.50863445, ...,  0.26382867,
#            0.02443784,  0.19732165],
#          [-0.10990372, -0.27354962, -0.469073  , ...,  0.23175785,
#            0.09461239,  0.23966607],
#          ...,
#          [ 0.19863637,  0.2886693 ,  0.41205204, ..., -0.21071325,
#           -0.01695971, -0.08851254],
#          [ 0.08721768,  0.03176624,  0.38265857, ..., -0.21185009,
#            0.09458322, -0.03851087],
#          [-0.11551886, -0.466995  ,  0.14228079, ..., -0.05374629,
#            0.24998438,  0.08351634]], dtype=float32),
#   'planetearth2': array([[-0.0548725 , -0.10023984, -0.4072721 , ...,  0.13564932,
#           -0.0852408 ,  0.03787278],
#          [-0.06701024, -0.15689877, -0.4373515 , ...,  0.16650732,
#           -0.0544785 ,  0.0413154 ],
#          [-0.08341216, -0.2073329 , -0.37274954, ...,  0.09907439,
#            0.00841118,  0.05217176],
#          ...,
#          [ 0.14175288,  0.18647254,  0.2974335 , ..., -0.14695668,
#            0.04984639,  0.01195036],
#          [ 0.03262067, -0.05304632,  0.07637809, ..., -0.13375749,
#            0.15468413,  0.10617927],
#          [-0.1543748 , -0.5044086 , -0.21246096, ..., -0.02490959,
#            0.33364823,  0.2014222 ]], dtype=float32),
#   'pulpfiction1': array([[-0.05329307, -0.13574305, -0.49021018, ..., -0.14088675,
#           -0.09585873, -0.14530148],
#          [-0.06101904, -0.15874267, -0.4785114 , ..., -0.14224872,
#           -0.06391511, -0.11179224],
#          [-0.08062527, -0.1938735 , -0.37896615, ..., -0.1537157 ,
#            0.01561109, -0.0744931 ],
#          ...,
#          [-0.10932761, -0.12849857,  0.01464676, ...,  0.41539073,
#            0.37759006,  0.33083397],
#          [-0.1086649 , -0.15545125, -0.03668961, ...,  0.34747273,
#            0.29811257,  0.2935747 ],
#          [-0.06356603, -0.12487376, -0.01621505, ...,  0.20627296,
#            0.26192096,  0.24465933]], dtype=float32),
#   'pulpfiction2': array([[-0.0952454 , -0.21835789, -0.345604  , ..., -0.03774092,
#            0.03823791, -0.01713596],
#          [-0.11564513, -0.28266162, -0.3376349 , ..., -0.03021997,
#            0.07542374, -0.00212021],
#          [-0.10870892, -0.29209045, -0.25320184, ..., -0.11718415,
#            0.11611849,  0.00463932],
#          ...,
#          [ 0.12267725,  0.16665837,  0.61756027, ...,  0.10356007,
#            0.02285512,  0.0489202 ],
#          [ 0.15283053,  0.11364197,  0.7093532 , ...,  0.102042  ,
#            0.12463357,  0.09593495],
#          [ 0.12916084,  0.05323643,  0.69127357, ...,  0.11594813,
#            0.21923795,  0.1493902 ]], dtype=float32),
#   'wot1': array([[-8.4162340e-02, -8.3774745e-02, -2.4763715e-01, ...,
#            1.4180900e-04, -1.2060414e-01, -1.9114910e-02],
#          [-8.1412345e-02, -1.1885456e-01, -3.1837022e-01, ...,
#           -1.0731103e-02, -1.0380222e-01, -6.6920727e-02],
#          [-1.2971713e-01, -3.6337537e-01, -4.0121883e-01, ...,
#            8.9779332e-02,  1.4331496e-01,  1.2441085e-01],
#          ...,
#          [-5.8789507e-02,  2.1839730e-02, -2.7415881e-01, ...,
#           -3.1540379e-01, -1.5828241e-01, -2.0998347e-01],
#          [-1.2209700e-01, -2.2754726e-01, -2.8736007e-01, ...,
#           -1.7938238e-01, -5.3049207e-02, -1.1079340e-01],
#          [-2.2833900e-01, -5.1003897e-01, -3.2913178e-01, ...,
#           -2.3168921e-03,  1.2250315e-01,  1.5499890e-03]], dtype=float32),
#   'wot2': array([[-0.14979923, -0.28063387, -0.4017908 , ...,  0.13687234,
#            0.00415656,  0.096677  ],
#          [-0.17647661, -0.327335  , -0.37528962, ...,  0.1578825 ,
#            0.03249481,  0.10444508],
#          [-0.13556753, -0.29477328, -0.31264445, ...,  0.1436819 ,
#            0.11158906,  0.15031391],
#          ...,
#          [-0.45885235, -0.94519883, -0.6413214 , ...,  0.2971744 ,
#            0.31742954,  0.22163777],
#          [-0.50227857, -0.919681  , -0.48233604, ...,  0.26642823,
#            0.37784111,  0.22497532],
#          [-0.4882068 , -0.7846589 , -0.3474792 , ...,  0.2049379 ,
#            0.47169638,  0.23050962]], dtype=float32)},
#  'sub-02': {'chaplin1': array([[-0.06132358, -0.06599215, -0.18375972, ...,  0.02282345,
#           -0.09762332, -0.01964379],
#          [-0.05801807, -0.11607617, -0.1553676 , ...,  0.05665506,
#           -0.07474452, -0.00895908],
#          [-0.05933114, -0.18112043, -0.10215503, ...,  0.03421657,
#            0.06146777,  0.13372496],
#          ...,
#          [-0.12216283, -0.10903128,  0.01350267, ..., -0.02135464,
#            0.25071055,  0.23455784],
#          [-0.1797673 , -0.19248861, -0.13871604, ...,  0.02085673,
#            0.3301311 ,  0.30420625],
#          [-0.27677423, -0.32304698, -0.23638947, ...,  0.13387668,
#            0.408351  ,  0.3987258 ]], dtype=float32),
#   'chaplin2': array([[-0.00085131, -0.04115976, -0.05307868, ..., -0.05508572,
#           -0.04379954, -0.01950427],
#          [-0.02946538, -0.09007039, -0.07265592, ..., -0.093009  ,
#           -0.04184178,  0.02090234],
#          [-0.05808842, -0.24703413, -0.13517791, ..., -0.1124594 ,
#            0.12951604,  0.14335981],
#          ...,
#          [-0.06789909, -0.03331283,  0.13440348, ..., -0.27755293,
#            0.382213  ,  0.34539014],
#          [-0.2032058 , -0.26034078, -0.01561245, ..., -0.2074949 ,
#            0.46661758,  0.4043506 ],
#          [-0.32763034, -0.46210244, -0.19484857, ..., -0.12373258,
#            0.5017512 ,  0.37403515]], dtype=float32),
#   'mononoke1': array([[-0.07177217,  0.12986092, -0.11539372, ...,  0.2980437 ,
#           -0.11034627, -0.0502947 ],
#          [-0.09507017,  0.12370677, -0.12041911, ...,  0.30306646,
#           -0.08474485, -0.0223343 ],
#          [-0.11107734,  0.03132783, -0.08853458, ...,  0.29206616,
#           -0.00196962,  0.08129953],
#          ...,
#          [-0.10044837, -0.1796506 ,  0.00372573, ...,  0.31747016,
#           -0.11717363,  0.10544223],
#          [-0.12137309, -0.16844292,  0.00169108, ...,  0.29539615,
#           -0.06193552,  0.10340226],
#          [-0.11755839, -0.18858181, -0.007584  , ...,  0.3002958 ,
#           -0.01175809,  0.16897975]], dtype=float32),
#   'mononoke2': array([[-0.02511228, -0.11494488, -0.23315826, ..., -0.1129566 ,
#            0.06703273,  0.07225258],
#          [-0.0319897 , -0.13300176, -0.23268819, ..., -0.12359449,
#            0.06250228,  0.09779064],
#          [-0.02677277, -0.12078326, -0.18244728, ..., -0.21242422,
#            0.11154531,  0.10624292],
#          ...,
#          [ 0.0197964 , -0.07847513, -0.02016968, ...,  0.12357973,
#           -0.0046611 , -0.07457656],
#          [ 0.00738656, -0.04772275, -0.08436732, ...,  0.18581644,
#           -0.12658879, -0.12796275],
#          [ 0.00269638, -0.09804349, -0.10996401, ...,  0.18373857,
#           -0.16864303, -0.10618961]], dtype=float32),
#   'passepartout1': array([[-0.0910098 , -0.06616776, -0.0485762 , ...,  0.05848194,
#            0.11402828,  0.09364432],
#          [-0.11806297, -0.14389196,  0.00784281, ...,  0.01195538,
#            0.15110272,  0.1069795 ],
#          [-0.14729543, -0.25000674, -0.02478077, ...,  0.01423943,
#            0.32751486,  0.20117244],
#          ...,
#          [ 0.01572012,  0.1095351 , -0.01968258, ..., -0.4713423 ,
#           -0.24815136, -0.30226615],
#          [-0.07282482, -0.05715621, -0.01283153, ..., -0.28088683,
#           -0.01037344, -0.09318273],
#          [-0.20300907, -0.19778489, -0.06775441, ..., -0.11506452,
#            0.21214727,  0.16269696]], dtype=float32),
#   'passepartout2': array([[ 0.03557343, -0.03320005, -0.05132366, ..., -0.00345049,
#            0.03571503,  0.02322186],
#          [ 0.0437383 , -0.03300281, -0.05218889, ..., -0.07864951,
#            0.0468142 ,  0.01608202],
#          [ 0.05441396, -0.09017439, -0.04911501, ..., -0.08368242,
#            0.07386687,  0.05057304],
#          ...,
#          [ 0.01648822,  0.1619675 , -0.20551737, ..., -0.1244983 ,
#           -0.06805132, -0.13056955],
#          [-0.02474913,  0.10799538, -0.1616742 , ...,  0.03142381,
#           -0.05487967, -0.03231785],
#          [-0.10602967, -0.09080705, -0.11530922, ...,  0.14013678,
#            0.11589953,  0.15152667]], dtype=float32),
#   'planetearth1': array([[-0.13958725,  0.06033496, -0.19541575, ...,  0.26528847,
#           -0.04170779,  0.02848119],
#          [-0.14874567,  0.06271572, -0.21772212, ...,  0.24341805,
#           -0.03024696,  0.05168872],
#          [-0.1442864 , -0.00640085, -0.18307623, ...,  0.22996217,
#            0.02480785,  0.0968127 ],
#          ...,
#          [-0.19595712,  0.0643556 ,  0.21484184, ..., -0.20734556,
#            0.02165475, -0.0784727 ],
#          [-0.24945518,  0.00070403,  0.19045588, ..., -0.1866144 ,
#            0.1557555 , -0.02682012],
#          [-0.3560921 , -0.12681298,  0.02352664, ..., -0.00965568,
#            0.26374117,  0.06070864]], dtype=float32),
#   'planetearth2': array([[-0.00223477,  0.09937576, -0.15173496, ...,  0.18330264,
#           -0.05169673, -0.02497523],
#          [-0.01732416,  0.09457483, -0.16405721, ...,  0.1858239 ,
#           -0.03786364, -0.0180007 ],
#          [-0.03891759,  0.05811847, -0.14031726, ...,  0.14578451,
#            0.00280014,  0.04373872],
#          ...,
#          [-0.08539048,  0.02745932,  0.11445135, ..., -0.27417094,
#            0.08799709,  0.10411366],
#          [-0.14933068, -0.04714216, -0.04143419, ..., -0.23486221,
#            0.18603589,  0.13790752],
#          [-0.20065552, -0.1569479 , -0.180367  , ..., -0.09746139,
#            0.2923162 ,  0.17370245]], dtype=float32),
#   'pulpfiction1': array([[ 0.05094669,  0.06160928, -0.21417642, ..., -0.19508621,
#           -0.0220681 ,  0.00060159],
#          [ 0.05848955,  0.04960668, -0.21249703, ..., -0.20964283,
#           -0.0121761 ,  0.00596221],
#          [ 0.04168783,  0.00515011, -0.13472776, ..., -0.1884467 ,
#            0.04203042,  0.06761824],
#          ...,
#          [-0.06845874, -0.23379712, -0.13576339, ...,  0.40723127,
#            0.1386999 ,  0.20380208],
#          [-0.05630834, -0.16070731, -0.11935156, ...,  0.30183622,
#            0.11213695,  0.1640013 ],
#          [-0.02344108, -0.08818136, -0.04552219, ...,  0.19182095,
#            0.10139161,  0.18941563]], dtype=float32),
#   'pulpfiction2': array([[ 0.01533294, -0.13650174, -0.17641425, ..., -0.10327314,
#            0.03371485,  0.0545949 ],
#          [-0.00131842, -0.12025899, -0.17712012, ..., -0.12683246,
#            0.08457273,  0.04943717],
#          [-0.00134236, -0.17066407, -0.13727677, ..., -0.20850118,
#            0.11377985,  0.11746005],
#          ...,
#          [-0.0690259 , -0.20412487,  0.34839374, ...,  0.19588804,
#           -0.00824196,  0.03780203],
#          [-0.13424581, -0.23697162,  0.31921285, ...,  0.18687467,
#            0.06855524,  0.0836778 ],
#          [-0.17673795, -0.3135914 ,  0.25729823, ...,  0.170764  ,
#            0.10505178,  0.20485969]], dtype=float32),
#   'wot1': array([[ 2.93474644e-04,  3.83131467e-02, -1.78910345e-01, ...,
#           -6.81663398e-04, -3.67729627e-02, -1.08132854e-01],
#          [-3.40063684e-02, -5.36063462e-02, -1.72141999e-01, ...,
#           -7.45461807e-02,  2.68775597e-03, -7.51361623e-02],
#          [-4.59822044e-02, -1.80389807e-01, -2.12713838e-01, ...,
#           -8.96172971e-03,  1.77036881e-01,  6.20392710e-02],
#          ...,
#          [-1.44336551e-01, -9.34399664e-03, -1.51733935e-01, ...,
#           -4.76069361e-01, -6.71702623e-02, -1.80379450e-01],
#          [-2.19450399e-01, -8.35961327e-02, -1.67683914e-01, ...,
#           -3.45067680e-01,  5.16934693e-02, -5.72521389e-02],
#          [-3.91708791e-01, -2.07192957e-01, -1.94398254e-01, ...,
#           -1.75447255e-01,  2.01760411e-01,  6.10263981e-02]], dtype=float32),
#   'wot2': array([[-0.09958184, -0.02854872, -0.23854417, ...,  0.10618767,
#           -0.05964435,  0.00183242],
#          [-0.09841439, -0.05484964, -0.20948914, ...,  0.08460432,
#           -0.02605538,  0.00827195],
#          [-0.09443265, -0.06597141, -0.15930668, ...,  0.05481488,
#            0.04592255,  0.07052132],
#          ...,
#          [-0.6376642 , -0.56396616, -0.43524617, ...,  0.09297545,
#            0.18281814, -0.00367711],
#          [-0.7572473 , -0.62419057, -0.3293467 , ...,  0.03582266,
#            0.24476206, -0.02015987],
#          [-0.7677666 , -0.6179178 , -0.2089001 , ..., -0.02390397,
#            0.30895793, -0.00947715]], dtype=float32)},
#  'sub-03': {'chaplin1': array([[-0.01245387, -0.15127268,  0.03802694, ...,  0.08157452,
#           -0.1841698 , -0.12126791],
#          [-0.02091928, -0.22298664, -0.02205476, ...,  0.16447353,
#           -0.17796133, -0.06776725],
#          [-0.11432396, -0.40825045, -0.07742354, ...,  0.26715803,
#           -0.03291927,  0.09966926],
#          ...,
#          [-0.03647489, -0.18150969,  0.30337486, ...,  0.12072362,
#            0.40012175,  0.24310806],
#          [-0.20084539, -0.6715015 , -0.01704044, ...,  0.25899383,
#            0.56902623,  0.20193477],
#          [-0.3471123 , -1.0220989 , -0.21237412, ...,  0.4769396 ,
#            0.7522109 ,  0.23623142]], dtype=float32),
#   'chaplin2': array([[-0.02266802, -0.037628  , -0.07304789, ..., -0.02951299,
#           -0.17005041, -0.10309524],
#          [-0.02981084, -0.05382881, -0.08164312, ..., -0.04201686,
#           -0.1394198 , -0.08039751],
#          [-0.16210201, -0.43284866, -0.22762476, ...,  0.09774781,
#            0.03753052,  0.05061712],
#          ...,
#          [-0.13044736, -0.14197665,  0.29366565, ..., -0.20912418,
#            0.54065764,  0.06950361],
#          [-0.296673  , -0.6284076 ,  0.0485648 , ...,  0.07425117,
#            0.7283434 ,  0.1356548 ],
#          [-0.44289175, -1.0818605 , -0.19731626, ...,  0.36689687,
#            0.82170564,  0.17338431]], dtype=float32),
#   'mononoke1': array([[ 0.12200979,  0.05071522, -0.14186554, ...,  0.29248765,
#           -0.24096876, -0.1487927 ],
#          [ 0.11974832,  0.00913807, -0.17998384, ...,  0.33247018,
#           -0.2696069 , -0.1037496 ],
#          [ 0.07572769, -0.06171395, -0.12818357, ...,  0.40468884,
#           -0.14202675,  0.04703191],
#          ...,
#          [-0.02688121, -0.13348453,  0.3131435 , ...,  0.3045237 ,
#            0.11595263,  0.08983216],
#          [-0.00277153, -0.05106726,  0.3226096 , ...,  0.31963488,
#            0.20521992,  0.12329162],
#          [ 0.01420354, -0.02937914,  0.36202306, ...,  0.34049818,
#            0.2524506 ,  0.14071323]], dtype=float32),
#   'mononoke2': array([[-0.07454409, -0.28509584, -0.21107459, ..., -0.02776994,
#           -0.04241326, -0.07890208],
#          [-0.09942926, -0.3868974 , -0.32053533, ..., -0.04808212,
#           -0.03447286, -0.07996935],
#          [-0.10529651, -0.33917755, -0.26393917, ..., -0.05625146,
#            0.04860621, -0.02635074],
#          ...,
#          [-0.00308062,  0.17437188,  0.17036632, ...,  0.03712867,
#           -0.00956212, -0.00511537],
#          [ 0.04008838,  0.19487819,  0.02440389, ...,  0.05375431,
#           -0.13056625, -0.18640634],
#          [ 0.05578166,  0.17960937,  0.09326208, ..., -0.00351455,
#           -0.28078923, -0.29642567]], dtype=float32),
#   'passepartout1': array([[-0.04782726, -0.15224859,  0.00244715, ...,  0.15135045,
#           -0.00410479,  0.1144098 ],
#          [-0.02249195, -0.12117451, -0.00625637, ...,  0.18131702,
#            0.01953246,  0.15930824],
#          [-0.11260694, -0.3282481 , -0.01022721, ...,  0.35348257,
#            0.22479294,  0.3054103 ],
#          ...,
#          [ 0.05329171, -0.03945064,  0.21973608, ..., -0.40753186,
#           -0.22975647, -0.3332218 ],
#          [-0.0719553 , -0.3045128 ,  0.2605288 , ..., -0.08881263,
#            0.11126924, -0.0474483 ],
#          [-0.22730614, -0.69733614,  0.13625662, ...,  0.25028157,
#            0.49781787,  0.11274004]], dtype=float32),
#   'passepartout2': array([[-0.02508681, -0.02295502, -0.1064769 , ..., -0.02682159,
#           -0.01497711, -0.07621136],
#          [-0.03640773, -0.03580675, -0.08818875, ..., -0.06621125,
#            0.00594863, -0.05125598],
#          [-0.06322817, -0.12285729, -0.09481605, ..., -0.02097074,
#            0.08101982,  0.02976284],
#          ...,
#          [ 0.08021141,  0.07175437, -0.01145744, ..., -0.09763876,
#           -0.10426912, -0.23691738],
#          [ 0.08085094, -0.03963045,  0.01426755, ...,  0.05359668,
#           -0.02928833, -0.14668298],
#          [-0.02987297, -0.29401314,  0.11390968, ...,  0.2379017 ,
#            0.22380571,  0.01883988]], dtype=float32),
#   'planetearth1': array([[-0.01141781, -0.16049874, -0.33328176, ...,  0.24051648,
#           -0.12461777, -0.09283443],
#          [-0.01020905, -0.2371549 , -0.4365106 , ...,  0.2424745 ,
#           -0.14817207, -0.08308327],
#          [-0.03269671, -0.26666376, -0.36584628, ...,  0.28581452,
#           -0.04833839,  0.01944153],
#          ...,
#          [ 0.0825173 ,  0.03603242,  0.31888875, ...,  0.13815576,
#            0.13099042,  0.09230399],
#          [ 0.02330264, -0.09951721,  0.34962645, ...,  0.21915844,
#            0.3136513 ,  0.15911436],
#          [-0.16002804, -0.56175727,  0.137519  , ...,  0.4535909 ,
#            0.47799847,  0.17514351]], dtype=float32),
#   'planetearth2': array([[-0.02057658, -0.10248703, -0.28910565, ...,  0.08693732,
#           -0.22424439, -0.16585052],
#          [-0.04000042, -0.19385317, -0.3842854 , ...,  0.1534833 ,
#           -0.24947235, -0.13503072],
#          [-0.0727433 , -0.2577652 , -0.34141982, ...,  0.14824173,
#           -0.14003924, -0.04890409],
#          ...,
#          [ 0.00663735,  0.00418621,  0.18101527, ..., -0.01413641,
#            0.18110217,  0.11749887],
#          [-0.0307895 , -0.21129736,  0.05974894, ...,  0.07635462,
#            0.28201464,  0.18717372],
#          [-0.17292313, -0.65879405, -0.11987278, ...,  0.25810704,
#            0.435163  ,  0.20284307]], dtype=float32),
#   'pulpfiction1': array([[-0.05503373, -0.08897457, -0.24587122, ..., -0.17883612,
#           -0.12456662, -0.23647068],
#          [-0.05388389, -0.1308971 , -0.25972748, ..., -0.17913434,
#           -0.13565077, -0.18068744],
#          [-0.06182459, -0.16445795, -0.19291502, ..., -0.09400117,
#           -0.059001  , -0.04542432],
#          ...,
#          [-0.09349302, -0.22044149,  0.11209571, ...,  0.2787043 ,
#            0.3767643 ,  0.287762  ],
#          [-0.07111281, -0.20733577,  0.00215955, ...,  0.21866757,
#            0.36821333,  0.25367838],
#          [-0.03138626, -0.0888413 ,  0.16904093, ...,  0.1555475 ,
#            0.34611255,  0.24675596]], dtype=float32),
#   'pulpfiction2': array([[-0.08515763, -0.21699107, -0.1091536 , ..., -0.01550054,
#           -0.09506613, -0.07353014],
#          [-0.14357437, -0.3200988 , -0.16363865, ..., -0.01211262,
#           -0.06963526, -0.05983034],
#          [-0.15133174, -0.34289318, -0.02426195, ..., -0.03045354,
#            0.03754464,  0.03894778],
#          ...,
#          [ 0.00634634,  0.17163658,  0.82083595, ...,  0.02279907,
#            0.22548503,  0.18213893],
#          [-0.03032768,  0.14059253,  0.8379744 , ...,  0.03481324,
#            0.32201245,  0.29035664],
#          [-0.05192962,  0.06808357,  0.8732729 , ...,  0.04120882,
#            0.41836035,  0.3621103 ]], dtype=float32),
#   'wot1': array([[ 0.02764505, -0.04595996, -0.09841447, ..., -0.08670431,
#           -0.20247513, -0.21559042],
#          [ 0.03654669, -0.03960475, -0.13664833, ..., -0.09213591,
#           -0.1602871 , -0.17669167],
#          [-0.07230447, -0.26847115, -0.09738099, ...,  0.10443708,
#            0.03553333,  0.0033203 ],
#          ...,
#          [-0.02936975, -0.16106749,  0.08678684, ..., -0.16749267,
#            0.21021214, -0.15134229],
#          [-0.10415628, -0.39556545,  0.02820614, ...,  0.16689554,
#            0.43102652, -0.07058244],
#          [-0.20779866, -0.71316695, -0.08902951, ...,  0.47204933,
#            0.6508809 ,  0.01417764]], dtype=float32),
#   'wot2': array([[-0.09828326, -0.27784726, -0.29336742, ...,  0.1554286 ,
#           -0.05187509, -0.05908102],
#          [-0.11278926, -0.3768586 , -0.35294962, ...,  0.18870646,
#           -0.06974486, -0.02687567],
#          [-0.12448502, -0.32912046, -0.20386547, ...,  0.23803905,
#            0.03876282,  0.11978935],
#          ...,
#          [-0.42599908, -1.2128654 , -0.6112321 , ...,  0.598459  ,
#            0.6143477 ,  0.04406779],
#          [-0.42803273, -1.194236  , -0.6134635 , ...,  0.6784178 ,
#            0.6818733 ,  0.15975648],
#          [-0.40284088, -1.0477524 , -0.4997424 , ...,  0.7358903 ,
#            0.68579435,  0.26144496]], dtype=float32)},
#  'sub-05': {'chaplin1': array([[-0.13918385, -0.1585171 , -0.10319345, ...,  0.09560557,
#           -0.06812744,  0.2144629 ],
#          [-0.15216774, -0.23300192, -0.0705494 , ...,  0.06595355,
#           -0.05663839,  0.20570543],
#          [-0.14549911, -0.34729862, -0.0621158 , ...,  0.05665185,
#           -0.00866012,  0.16328046],
#          ...,
#          [ 0.01721336, -0.20898694,  0.11152169, ..., -0.03230827,
#            0.33561027,  0.15751702],
#          [ 0.06983791, -0.5432619 , -0.13584544, ...,  0.08220366,
#            0.3832814 ,  0.05288582],
#          [ 0.06586598, -0.85779625, -0.33266655, ...,  0.24420199,
#            0.5374996 , -0.10456532]], dtype=float32),
#   'chaplin2': array([[-0.07586955, -0.05444475, -0.10654448, ..., -0.01700905,
#           -0.20450553,  0.04928857],
#          [-0.08370925, -0.10014347, -0.07733417, ..., -0.0368031 ,
#           -0.17130381,  0.05536124],
#          [-0.086537  , -0.3483563 , -0.11637653, ..., -0.03966736,
#           -0.08100235,  0.0181163 ],
#          ...,
#          [ 0.18897974, -0.1453271 , -0.04781706, ..., -0.07072463,
#            0.05145775, -0.22508955],
#          [ 0.11093518, -0.4911226 , -0.25600868, ...,  0.03695352,
#            0.22050054, -0.31346706],
#          [ 0.00418283, -0.8440144 , -0.5140929 , ...,  0.16990866,
#            0.3816175 , -0.40741906]], dtype=float32),
#   'mononoke1': array([[-1.04365252e-01,  1.41124383e-01, -1.05104282e-01, ...,
#            1.70751274e-01, -1.26847699e-01,  2.46027529e-01],
#          [-1.06179267e-01,  1.21129274e-01, -9.09141451e-02, ...,
#            1.74545422e-01, -1.09591275e-01,  2.66933054e-01],
#          [-1.03071712e-01,  4.71979752e-02, -7.59591758e-02, ...,
#            1.92539766e-01, -2.46757939e-02,  2.78280735e-01],
#          ...,
#          [-1.49240255e-01, -2.47420758e-01, -5.58654778e-02, ...,
#            2.50928670e-01,  1.55145258e-01,  3.16288710e-01],
#          [-1.12388782e-01, -1.84960529e-01, -4.52325270e-02, ...,
#            2.35010237e-01,  2.02316225e-01,  2.53567934e-01],
#          [-1.00208178e-01, -1.80547982e-01, -2.38116831e-04, ...,
#            2.15182275e-01,  2.44873196e-01,  1.98077559e-01]], dtype=float32),
#   'mononoke2': array([[-0.05220755, -0.14913823, -0.14437537, ..., -0.03989817,
#           -0.15731692, -0.0588407 ],
#          [-0.05648026, -0.22107169, -0.14678955, ..., -0.05759859,
#           -0.12518936, -0.06327157],
#          [-0.05027501, -0.25490358, -0.16037095, ..., -0.10064495,
#           -0.05811384, -0.10244854],
#          ...,
#          [-0.01487257,  0.04058575, -0.02475088, ..., -0.10861899,
#            0.21877262,  0.03537211],
#          [-0.05091356,  0.05850815, -0.11934312, ...,  0.00684017,
#            0.13701662,  0.11288845],
#          [-0.08363102,  0.02411436, -0.08639334, ...,  0.0727655 ,
#            0.0638203 ,  0.16616376]], dtype=float32),
#   'passepartout1': array([[-0.08208791, -0.19205737, -0.03503088, ...,  0.09225306,
#            0.08661371,  0.03638535],
#          [-0.0867956 , -0.2134518 , -0.02333038, ...,  0.05751064,
#            0.12861955,  0.02989093],
#          [-0.0951714 , -0.35019428, -0.01962601, ...,  0.06376559,
#            0.28040555, -0.02520861],
#          ...,
#          [-0.10167406, -0.02709517, -0.07600766, ..., -0.43060187,
#           -0.24906632, -0.06074761],
#          [-0.05548612, -0.20971131, -0.06213783, ..., -0.26851428,
#           -0.06403834, -0.00561245],
#          [-0.02621596, -0.49441892, -0.14095934, ..., -0.04896326,
#            0.22616124, -0.09126763]], dtype=float32),
#   'passepartout2': array([[ 0.04319536,  0.03690601, -0.08180276, ...,  0.01696688,
#           -0.06200435, -0.04028627],
#          [ 0.04154406,  0.04898518, -0.08581229, ...,  0.02381362,
#           -0.02529074, -0.03396107],
#          [ 0.03764233,  0.00456327, -0.07611708, ..., -0.01866437,
#            0.04972739, -0.04785053],
#          ...,
#          [-0.16817744,  0.08586369, -0.21180224, ..., -0.29334325,
#           -0.09029944, -0.11422423],
#          [-0.13336274, -0.02743505, -0.19832455, ..., -0.16531795,
#            0.01491262,  0.05644312],
#          [-0.07579742, -0.18515514, -0.20286497, ...,  0.00133721,
#            0.10614564,  0.12826338]], dtype=float32),
#   'planetearth1': array([[-0.15603507, -0.13563418, -0.2021687 , ...,  0.2650419 ,
#           -0.09793024,  0.28949147],
#          [-0.16020301, -0.18151692, -0.1901841 , ...,  0.25883484,
#           -0.10322046,  0.2941788 ],
#          [-0.14437285, -0.24438247, -0.1229735 , ...,  0.2268098 ,
#           -0.04529534,  0.28537053],
#          ...,
#          [-0.06831331,  0.06250843,  0.16907106, ..., -0.2105729 ,
#            0.1669369 , -0.12205561],
#          [-0.01946446, -0.0507905 ,  0.16071902, ..., -0.14071843,
#            0.27233595, -0.05768614],
#          [ 0.04783089, -0.39307445, -0.06866217, ...,  0.06103575,
#            0.35986292,  0.01557924]], dtype=float32),
#   'planetearth2': array([[-0.1020886 , -0.03353171, -0.20588222, ...,  0.1624463 ,
#           -0.19610041,  0.29870373],
#          [-0.09820588, -0.0995198 , -0.21028364, ...,  0.17451374,
#           -0.19838265,  0.32287163],
#          [-0.08008792, -0.2092637 , -0.14881861, ...,  0.14664961,
#           -0.12663335,  0.28210118],
#          ...,
#          [-0.02207221,  0.02949875,  0.2195121 , ..., -0.19474664,
#            0.11673775, -0.16275226],
#          [ 0.01808903, -0.1133561 ,  0.14095281, ..., -0.16890354,
#            0.20241973, -0.14025806],
#          [ 0.04987693, -0.42570502, -0.09381985, ..., -0.0640173 ,
#            0.2795777 , -0.04765778]], dtype=float32),
#   'pulpfiction1': array([[-6.9741376e-02, -3.8690828e-02, -1.7938298e-01, ...,
#           -9.3220554e-02, -2.5525540e-01,  1.5147886e-02],
#          [-6.7936286e-02, -8.3345428e-02, -1.5228844e-01, ...,
#           -1.2916289e-01, -2.3460247e-01, -5.3499825e-06],
#          [-5.7778873e-02, -1.4871883e-01, -6.5194085e-02, ...,
#           -1.9484459e-01, -1.4660975e-01, -2.2773352e-02],
#          ...,
#          [-4.5656413e-03, -2.5078407e-01, -2.5400694e-02, ...,
#            2.5785279e-01,  4.6748084e-01,  2.3252778e-01],
#          [ 2.0167245e-02, -2.7296454e-01, -4.3609180e-02, ...,
#            2.1880575e-01,  4.3401802e-01,  1.4306152e-01],
#          [ 1.7507263e-02, -2.0844322e-01, -1.1562608e-02, ...,
#            1.7007345e-01,  4.1301012e-01,  1.3192561e-01]], dtype=float32),
#   'pulpfiction2': array([[-4.94932346e-02, -1.72542930e-01, -1.86986282e-01, ...,
#           -4.16705087e-02, -1.19826734e-01, -5.89427799e-02],
#          [-5.38857244e-02, -2.80001372e-01, -1.94789022e-01, ...,
#           -6.04603663e-02, -1.18398175e-01, -4.82606068e-02],
#          [-4.28891443e-02, -3.34248960e-01, -1.05618179e-01, ...,
#           -1.08224921e-01, -3.94777805e-02, -4.85155955e-02],
#          ...,
#          [ 8.31158832e-05,  1.62831903e-01,  1.46946386e-01, ...,
#           -1.69220939e-03,  5.57170928e-01,  1.00825094e-02],
#          [-1.13133322e-02,  5.43843545e-02,  2.51162797e-01, ...,
#           -4.78096381e-02,  7.22489953e-01, -7.53349364e-02],
#          [-2.47409903e-02, -6.34239614e-02,  3.13769758e-01, ...,
#           -7.95686245e-02,  8.10995281e-01, -1.21183336e-01]], dtype=float32),
#   'wot1': array([[-0.05412927, -0.17608333, -0.04452239, ..., -0.0232217 ,
#           -0.14980596,  0.0413323 ],
#          [-0.07157122, -0.17325935, -0.05492731, ..., -0.02669405,
#           -0.1691007 ,  0.05229221],
#          [-0.09107087, -0.33274877, -0.09167944, ..., -0.03123905,
#           -0.07680245, -0.02605992],
#          ...,
#          [-0.15502478, -0.13137113, -0.19566976, ..., -0.3030247 ,
#           -0.15287831, -0.15450414],
#          [-0.07841176, -0.35854757, -0.20297189, ..., -0.23347598,
#           -0.05945228, -0.17901187],
#          [-0.08925184, -0.59919953, -0.2872283 , ..., -0.07233491,
#            0.09417298, -0.25117192]], dtype=float32),
#   'wot2': array([[-0.11406657, -0.2607342 , -0.14520997, ...,  0.20612654,
#           -0.16086264,  0.11283638],
#          [-0.10436221, -0.35225445, -0.1555563 , ...,  0.2163615 ,
#           -0.15563121,  0.1351032 ],
#          [-0.10323034, -0.34662968, -0.08670101, ...,  0.20305079,
#           -0.11939349,  0.12334866],
#          ...,
#          [-0.28508255, -0.9871366 , -0.52553725, ...,  0.30024105,
#            0.40565813, -0.35098055],
#          [-0.3908669 , -1.0379149 , -0.5099389 , ...,  0.37147743,
#            0.4691196 , -0.4831528 ],
#          [-0.46176475, -0.95204616, -0.50467134, ...,  0.36874375,
#            0.47909734, -0.57528424]], dtype=float32)}}

# %%
import time
if not os.path.exists(output_path):
    os.makedirs(output_path)
# Save the ensemble predictions
output_file_name = f'new_fmri_predictions_ood_top_{top_k}_' + f'{time.strftime("%Y%m%d-%H%M%S")}.npy'
ensemble_output_path = os.path.join(output_path, output_file_name)
np.save(ensemble_output_path, ensemble_predictions)

# %%
# zip the npy file
import zipfile
zip_file_name = output_file_name.replace('.npy', '.zip')
zip_file_path = os.path.join(output_path, zip_file_name)
with zipfile.ZipFile(zip_file_path, 'w') as zipf:
    zipf.write(ensemble_output_path, arcname=output_file_name)

# %%
ensemble_output_path
# Out:
# 'ensenmble_results/new_fmri_predictions_ood_top_1_20250712-231704.npy'

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
