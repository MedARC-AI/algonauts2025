# %%
from pathlib import Path
from collections import defaultdict

from torch.utils.data import DataLoader

import data

# %%
from importlib import reload

reload(data)
# Out:
# <module 'data' from '/home/connor/algonauts2025.clean/src/data.py'>

# %%
root_dir = Path("..").resolve()

data_dir = root_dir / "datasets/algonauts_2025.competitors"
sharded_feature_root = root_dir / "datasets/features.sharded"
merged_feature_root = root_dir / "datasets/features.merged"

# %%
friends_fmri = data.load_algonauts2025_friends_fmri(data_dir)
movie10_fmri = data.load_algonauts2025_movie10_fmri(data_dir)

# %%
assert len(friends_fmri) == 287
assert len(movie10_fmri) == 61

# %%
sample = friends_fmri["s01e05b"]
print("Sample shape (NTC):", sample.shape, sample.dtype)
# Out:
# Sample shape (NTC): (4, 468, 1000) float32

# %%
stimuli_features = defaultdict(dict)

# %%
sharded_models_layers = [
    ("whisper", "layers.12.fc2"),
    ("internvl3_8b_8bit", "language_model.model.layers.20.post_attention_layernorm"),
]

for model, layer in sharded_models_layers:
    stimuli_features[f"{model}/{layer}"].update(
        data.load_sharded_features(
            sharded_feature_root,
            model=model,
            layer=layer,
            series="friends",
        )
    )
    stimuli_features[f"{model}/{layer}"].update(
        data.load_sharded_features(
            sharded_feature_root,
            model=model,
            layer=layer,
            series="movie10",
        )
    )

# %%
merged_models_layers = [
    ("meta-llama__Llama-3.2-1B", "model.layers.7", "context-long"),
]

for model, layer, stem in merged_models_layers:
    stimuli_features[f"{model}/{layer}"].update(
        data.load_merged_features(
            root=merged_feature_root,
            model=model,
            layer=layer,
            series="friends",
            stem=stem,
        )
    )
    stimuli_features[f"{model}/{layer}"].update(
        data.load_merged_features(
            root=merged_feature_root,
            model=model,
            layer=layer,
            series="movie10",
            stem=stem,
        )
    )

# %%
all_fmri_episodes = list(friends_fmri) + list(movie10_fmri)
all_fmri_episodes_no_runs = [
    ep[0] if isinstance(ep, tuple) else ep for ep in all_fmri_episodes
]

# %%
all_feat_episodes = [list(feats) for feats in stimuli_features.values()]
for episode_list in all_feat_episodes:
    assert set(episode_list) == set(all_feat_episodes[0])
all_feat_episodes = all_feat_episodes[0]

# %%
for episode in all_feat_episodes:
    shapes = {layer: feats[episode].shape for layer, feats in stimuli_features.items()}
    if len(set(shape[0] for shape in shapes.values())) > 1:
        print(episode, shapes)
# Out:
# s01e03b {'whisper/layers.12.fc2': (472, 1280), 'internvl3_8b_8bit/language_model.model.layers.20.post_attention_layernorm': (472, 3584), 'meta-llama__Llama-3.2-1B/model.layers.7': (471, 2048)}
# s02e20a {'whisper/layers.12.fc2': (449, 1280), 'internvl3_8b_8bit/language_model.model.layers.20.post_attention_layernorm': (449, 3584), 'meta-llama__Llama-3.2-1B/model.layers.7': (448, 2048)}
# s03e03a {'whisper/layers.12.fc2': (453, 1280), 'internvl3_8b_8bit/language_model.model.layers.20.post_attention_layernorm': (483, 3584), 'meta-llama__Llama-3.2-1B/model.layers.7': (453, 2048)}
# s03e03b {'whisper/layers.12.fc2': (453, 1280), 'internvl3_8b_8bit/language_model.model.layers.20.post_attention_layernorm': (466, 3584), 'meta-llama__Llama-3.2-1B/model.layers.7': (453, 2048)}
# s03e04a {'whisper/layers.12.fc2': (473, 1280), 'internvl3_8b_8bit/language_model.model.layers.20.post_attention_layernorm': (450, 3584), 'meta-llama__Llama-3.2-1B/model.layers.7': (473, 2048)}
# s03e04b {'whisper/layers.12.fc2': (473, 1280), 'internvl3_8b_8bit/language_model.model.layers.20.post_attention_layernorm': (473, 3584), 'meta-llama__Llama-3.2-1B/model.layers.7': (472, 2048)}
# s03e17b {'whisper/layers.12.fc2': (453, 1280), 'internvl3_8b_8bit/language_model.model.layers.20.post_attention_layernorm': (453, 3584), 'meta-llama__Llama-3.2-1B/model.layers.7': (452, 2048)}
# s05e23d {'whisper/layers.12.fc2': (488, 1280), 'internvl3_8b_8bit/language_model.model.layers.20.post_attention_layernorm': (488, 3584), 'meta-llama__Llama-3.2-1B/model.layers.7': (487, 2048)}
# s06e23a {'whisper/layers.12.fc2': (486, 1280), 'internvl3_8b_8bit/language_model.model.layers.20.post_attention_layernorm': (486, 3584), 'meta-llama__Llama-3.2-1B/model.layers.7': (485, 2048)}
# s07e10a {'whisper/layers.12.fc2': (459, 1280), 'internvl3_8b_8bit/language_model.model.layers.20.post_attention_layernorm': (459, 3584), 'meta-llama__Llama-3.2-1B/model.layers.7': (458, 2048)}
# wolf12 {'whisper/layers.12.fc2': (406, 1280), 'internvl3_8b_8bit/language_model.model.layers.20.post_attention_layernorm': (406, 3584), 'meta-llama__Llama-3.2-1B/model.layers.7': (407, 2048)}

# %%
print(sorted(set(all_feat_episodes) - set(all_fmri_episodes_no_runs)))
print(sorted(set(all_fmri_episodes_no_runs) - set(all_feat_episodes)))
# Out:
# ['s04e01a', 's04e01b', 's04e13b', 's05e20a', 's06e03a', 's07e01a', 's07e01b', 's07e02a', 's07e02b', 's07e03a', 's07e03b', 's07e04a', 's07e04b', 's07e05a', 's07e05b', 's07e06a', 's07e06b', 's07e07a', 's07e07b', 's07e08a', 's07e08b', 's07e09a', 's07e09b', 's07e10a', 's07e10b', 's07e11a', 's07e11b', 's07e12a', 's07e12b', 's07e13a', 's07e13b', 's07e14a', 's07e14b', 's07e15a', 's07e15b', 's07e16a', 's07e16b', 's07e16c', 's07e17a', 's07e17b', 's07e18a', 's07e18b', 's07e19a', 's07e19b', 's07e20a', 's07e20b', 's07e21a', 's07e21b', 's07e22a', 's07e22b', 's07e23a', 's07e23b', 's07e23c', 's07e23d']
# []

# %%
for ep in all_fmri_episodes:
    if isinstance(ep, tuple) and ep[1] == 2:
        print(ep)
# Out:
# ('figures01', 2)
# ('figures02', 2)
# ('figures03', 2)
# ('figures04', 2)
# ('figures05', 2)
# ('figures06', 2)
# ('figures07', 2)
# ('figures08', 2)
# ('figures09', 2)
# ('figures10', 2)
# ('figures11', 2)
# ('figures12', 2)
# ('life01', 2)
# ('life02', 2)
# ('life03', 2)
# ('life04', 2)
# ('life05', 2)

# %%
train_episode_list = list(
    filter(
        data.episode_filter(seasons=range(6), movies=["bourne", "wolf"]),
        all_fmri_episodes,
    ),
)

# %%
for ep in train_episode_list:
    print(ep)
# Out:
# s01e01a
# s01e01b
# s01e02a
# s01e02b
# s01e03a
# s01e03b
# s01e04a
# s01e04b
# s01e05a
# s01e05b
# s01e06a
# s01e06b
# s01e07a
# s01e07b
# s01e08a
# s01e08b
# s01e09a
# s01e09b
# s01e10a
# s01e10b
# s01e11a
# s01e11b
# s01e12a
# s01e12b
# s01e13a
# s01e13b
# s01e14a
# s01e14b
# s01e15a
# s01e15b
# s01e16a
# s01e16b
# s01e17a
# s01e17b
# s01e18a
# s01e18b
# s01e19a
# s01e19b
# s01e20a
# s01e20b
# s01e21a
# s01e21b
# s01e22a
# s01e22b
# s01e23a
# s01e23b
# s01e24a
# s01e24b
# s02e01a
# s02e01b
# s02e02a
# s02e02b
# s02e03a
# s02e03b
# s02e04a
# s02e04b
# s02e05a
# s02e05b
# s02e06a
# s02e06b
# s02e07a
# s02e07b
# s02e08a
# s02e08b
# s02e09a
# s02e09b
# s02e10a
# s02e10b
# s02e11a
# s02e11b
# s02e12a
# s02e12b
# s02e13a
# s02e13b
# s02e14a
# s02e14b
# s02e15a
# s02e15b
# s02e16a
# s02e16b
# s02e17a
# s02e17b
# s02e18a
# s02e18b
# s02e19a
# s02e19b
# s02e20a
# s02e20b
# s02e21a
# s02e21b
# s02e22a
# s02e22b
# s02e23a
# s02e23b
# s02e24a
# s02e24b
# s03e01a
# s03e01b
# s03e02a
# s03e02b
# s03e03a
# s03e03b
# s03e04a
# s03e04b
# s03e05a
# s03e05b
# s03e06a
# s03e06b
# s03e07a
# s03e07b
# s03e08a
# s03e08b
# s03e09a
# s03e09b
# s03e10a
# s03e10b
# s03e11a
# s03e11b
# s03e12a
# s03e12b
# s03e13a
# s03e13b
# s03e14a
# s03e14b
# s03e15a
# s03e15b
# s03e16a
# s03e16b
# s03e17a
# s03e17b
# s03e18a
# s03e18b
# s03e19a
# s03e19b
# s03e20a
# s03e20b
# s03e21a
# s03e21b
# s03e22a
# s03e22b
# s03e23a
# s03e23b
# s03e24a
# s03e24b
# s03e25a
# s03e25b
# s04e02a
# s04e02b
# s04e03a
# s04e03b
# s04e04a
# s04e04b
# s04e05a
# s04e05b
# s04e06a
# s04e06b
# s04e07a
# s04e07b
# s04e08a
# s04e08b
# s04e09a
# s04e09b
# s04e10a
# s04e10b
# s04e11a
# s04e11b
# s04e12a
# s04e12b
# s04e13a
# s04e14a
# s04e14b
# s04e15a
# s04e15b
# s04e16a
# s04e16b
# s04e17a
# s04e17b
# s04e18a
# s04e18b
# s04e19a
# s04e19b
# s04e20a
# s04e20b
# s04e21a
# s04e21b
# s04e22a
# s04e22b
# s04e23a
# s04e23b
# s04e23c
# s04e23d
# s05e01a
# s05e01b
# s05e02a
# s05e02b
# s05e03a
# s05e03b
# s05e04a
# s05e04b
# s05e05a
# s05e05b
# s05e06a
# s05e06b
# s05e07a
# s05e07b
# s05e08a
# s05e08b
# s05e09a
# s05e09b
# s05e10a
# s05e10b
# s05e11a
# s05e11b
# s05e12a
# s05e12b
# s05e13a
# s05e13b
# s05e14a
# s05e14b
# s05e15a
# s05e15b
# s05e16a
# s05e16b
# s05e17a
# s05e17b
# s05e18a
# s05e18b
# s05e19a
# s05e19b
# s05e20b
# s05e21a
# s05e21b
# s05e22a
# s05e22b
# s05e23a
# s05e23b
# s05e23c
# s05e23d
# ('bourne01', 1)
# ('bourne02', 1)
# ('bourne03', 1)
# ('bourne04', 1)
# ('bourne05', 1)
# ('bourne06', 1)
# ('bourne07', 1)
# ('bourne08', 1)
# ('bourne09', 1)
# ('bourne10', 1)
# ('wolf01', 1)
# ('wolf02', 1)
# ('wolf03', 1)
# ('wolf04', 1)
# ('wolf05', 1)
# ('wolf06', 1)
# ('wolf07', 1)
# ('wolf08', 1)
# ('wolf09', 1)
# ('wolf10', 1)
# ('wolf11', 1)
# ('wolf12', 1)
# ('wolf13', 1)
# ('wolf14', 1)
# ('wolf15', 1)
# ('wolf16', 1)
# ('wolf17', 1)

# %%
merged_fmri = {**friends_fmri, **movie10_fmri}

# %%
train_dataset = data.Algonauts2025Dataset(
    episode_list=train_episode_list,
    fmri_data=merged_fmri,
    feat_data=list(stimuli_features.values()),
    sample_length=64,
    num_samples=400,
    shuffle=True,
    seed=42,
)

# %%
train_loader = DataLoader(train_dataset, batch_size=4)

# %%
for batch in train_loader:
    print("episode:", batch["episode"])
    print("fmri:", batch["fmri"].shape)
    print("features:", [feat.shape for feat in batch["features"]])
# Out:
# episode: ['s01e13a', 'wolf17', 's02e19a', 's02e24b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e20a', 's01e24a', 's03e22a', 's01e07a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['wolf11', 's03e03a', 's05e01a', 's04e20a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e17b', 's05e18a', 's03e25a', 's05e03b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e23a', 's04e05a', 'wolf08', 's01e02b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e18b', 's03e02a', 's03e25b', 's04e22b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e15a', 's04e05b', 's02e04a', 's05e07b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['wolf15', 'bourne06', 's01e14a', 's05e04b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e21a', 's02e17a', 's05e01b', 's02e02a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['bourne10', 'wolf16', 'wolf09', 's02e12a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e08a', 'wolf01', 's02e09a', 's03e06b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e07a', 's05e14b', 's05e13b', 's02e14b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['bourne03', 's03e03b', 's02e02b', 's04e02b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e18b', 's04e04a', 's03e23a', 's01e24b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e21b', 's02e18a', 'bourne04', 's03e15a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e01a', 's01e04b', 's03e10b', 's05e13a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e18b', 's05e23c', 's04e03a', 's01e19b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e16b', 's05e09b', 's04e11b', 's03e20a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e05a', 's01e11a', 's05e08b', 'wolf03']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e17b', 's01e05a', 's04e09b', 's05e17a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e13b', 's03e18a', 's01e15b', 'bourne07']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e16b', 's03e16b', 's04e15b', 'wolf14']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e05b', 's03e20b', 's02e06b', 's04e14b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e05b', 's03e12a', 's01e03a', 's03e09a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e07a', 's02e10b', 's04e03b', 's02e24a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e13a', 's05e05a', 's02e13a', 's04e02a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e24b', 's03e19b', 's04e23b', 's03e19a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e14b', 's04e19b', 's02e05a', 's01e01a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['bourne08', 'wolf10', 's01e02a', 's03e07a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e17a', 's02e11a', 's02e17b', 's03e13b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e16a', 's02e01a', 's04e08a', 's02e04b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e20b', 's02e10a', 's02e03a', 's04e23a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e20a', 's01e15a', 's05e12b', 's03e06a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e04a', 's03e13a', 'wolf12', 's04e15a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e17a', 's05e10a', 's04e23c', 's02e22b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['wolf13', 's01e20b', 's04e08b', 's01e07b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e06b', 's04e12a', 's01e03b', 's02e19b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e14a', 's04e16a', 's05e09a', 'bourne05']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e22a', 's04e10a', 's02e16a', 's05e23a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e12b', 's05e23b', 's03e10a', 's02e18b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e14b', 's01e23b', 's03e04b', 's02e22a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e10a', 's05e02a', 's02e20b', 's05e12a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e08b', 's02e13b', 's04e19a', 's01e11b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e04b', 's02e23b', 's05e19b', 's02e09b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['bourne09', 's03e02b', 's02e12b', 's05e16a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e08a', 's04e06a', 's04e21b', 's03e15b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e18a', 'wolf07', 's03e11b', 's02e14a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e21a', 's01e06a', 's03e11a', 's05e06a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e07b', 's02e08b', 's04e21a', 's01e01b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e22a', 's03e14a', 's01e09b', 's04e12b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['wolf04', 's02e03b', 's02e15a', 's05e15b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e21a', 's02e11b', 's05e21b', 's03e17b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e10b', 's03e05b', 's05e14a', 's05e22a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e06b', 's03e24a', 's05e11b', 's05e11a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e22b', 'bourne02', 's04e09a', 's02e07b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e05b', 's05e16b', 's01e12b', 's04e11a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e22b', 's01e08b', 's04e17b', 's02e07a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e07b', 's03e21b', 's04e23d', 's01e16b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['bourne01', 's01e09a', 's01e23a', 'wolf06']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e19a', 'wolf02', 's05e03a', 's01e18a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e16a', 's02e06a', 's05e06b', 's01e18b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e15b', 's04e20b', 's02e01b', 's01e04a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e04a', 's04e17a', 's03e22b', 'wolf05']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e21b', 's03e08a', 's01e12a', 's01e10b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e10b', 's03e09b', 's05e23d', 's01e08a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e23b', 's05e02b', 's01e19a', 's03e01b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e21a', 's04e02b', 's01e20b', 's01e06b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e03a', 's05e17b', 's02e04b', 'bourne07']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e19a', 'bourne08', 'wolf10', 's01e15b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e24a', 'wolf06', 's03e23b', 's03e04a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e04b', 's05e08b', 's03e22b', 's03e16b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e14b', 's01e21b', 's01e13a', 'wolf04']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e08b', 's03e08b', 's03e17a', 's05e07a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e18a', 's02e23a', 's05e06a', 's04e17b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e15a', 'bourne09', 's05e08a', 'bourne04']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e03a', 's04e15b', 's04e05a', 's05e22a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e06a', 's03e10b', 'wolf13', 's05e21b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e07b', 's02e02b', 's02e03a', 's04e02a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e23d', 's02e18b', 's01e16a', 's03e01a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e12b', 's01e13b', 's01e14b', 's02e24a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e06b', 's02e13b', 's01e07a', 's02e22b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e07b', 'wolf11', 's03e13a', 's03e11b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e01b', 's05e05a', 's03e04b', 's05e18b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e20a', 's02e17b', 's03e14a', 's01e19a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e13a', 's03e02a', 's02e16b', 's04e10a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e22b', 's04e15a', 'wolf14', 's02e20b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['bourne02', 's02e15b', 's02e14a', 's05e21a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e11a', 's01e12a', 's02e16a', 's02e05a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e15a', 'wolf15', 's04e04b', 's03e06a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e20a', 's01e04a', 's05e23a', 's04e19b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e01a', 's03e21a', 's04e16a', 's02e10b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s03e14b', 's05e17a', 's03e18b', 's03e09b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['wolf05', 's04e20a', 's05e19b', 's01e08a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e11b', 's03e17b', 's01e05a', 's05e09a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['wolf07', 's03e15b', 's05e16b', 's03e16a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e22b', 's02e07a', 's04e05b', 's04e11b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s04e21a', 's01e03b', 'wolf08', 's03e03a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s05e23d', 's05e15a', 'wolf17', 's03e07b']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s02e21a', 's01e12b', 's02e23b', 's04e11a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
# episode: ['s01e11a', 's04e23a', 's04e07b', 's01e17a']
# fmri: torch.Size([4, 4, 64, 1000])
# features: [torch.Size([4, 64, 1280]), torch.Size([4, 64, 3584]), torch.Size([4, 64, 2048])]
